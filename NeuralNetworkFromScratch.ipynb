# %% [markdown]
# ## **Creating a Neural Network From Scrath With Numpy**

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets

# %%
X, y = sklearn.datasets.make_moons(200, noise=0.15)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
X.shape, y.shape
# Out:
# ((200, 2), (200,))

# %%
input_neurons = 2
output_neurons = 2
samples = X.shape[0]
learning_rate = 0.001
lamba = 0.01
