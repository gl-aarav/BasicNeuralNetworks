# %% [markdown]
# ## **Creating a Neural Network From Scrath With Numpy**

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets

# %%
X, y = sklearn.datasets.make_moons(200, noise=0.15)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
X.shape, y.shape
# Out:
# ((200, 2), (200,))

# %%
input_neurons = 2
output_neurons = 2
samples = X.shape[0]
learning_rate = 0.001
lambda_reg = 0.01

# %%
model_dic = {'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model_dic = {'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2}
#
# NameError: name 'W1' is not defined

# %%
def retrieve(model_dict):
    W1 = model_dic['W1']
    b1 = model_dic['b1']
    W2 = model_dic['W2']
    b2 = model_dic['b2']
    return W1, b1, W2, b2

# %%
def forward(x, model_dict):
    W1, b1, W2, b2 = retrieve(model_dict)
    z1 = x.dot(W1) + b1
    a1 = np.tanh(z1)
    z2 = a1.dot(W2) + b2
    a2 = np.tanh(z2)
    exp_scores = np.exp(a2)
    sofmax = exp_scores / np.sum(exp_scores, dim = 1, keepdims=True)
    return softmax
